# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Описание данных</a></span></li></ul></li></ul></li><li><span><a href="#Подготовка-данных." data-toc-modified-id="Подготовка-данных.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных.</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Посмотрите,-сколько-игр-выпускалось-в-разные-годы.-Важны-ли-данные-за-все-периоды?" data-toc-modified-id="Посмотрите,-сколько-игр-выпускалось-в-разные-годы.-Важны-ли-данные-за-все-периоды?-3.0.0.1"><span class="toc-item-num">3.0.0.1&nbsp;&nbsp;</span>Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Вывод</a></span><ul class="toc-item"><li><span><a href="#Посмотрите,-как-менялись-продажи-по-платформам.-Выберите-платформы-с-наибольшими-суммарными-продажами-и-постройте-распределение-по-годам.-За-какой-характерный-срок-появляются-новые-и-исчезают-старые-платформы?" data-toc-modified-id="Посмотрите,-как-менялись-продажи-по-платформам.-Выберите-платформы-с-наибольшими-суммарными-продажами-и-постройте-распределение-по-годам.-За-какой-характерный-срок-появляются-новые-и-исчезают-старые-платформы?-3.0.1.1"><span class="toc-item-num">3.0.1.1&nbsp;&nbsp;</span>Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>Вывод</a></span><ul class="toc-item"><li><span><a href="#Анализ" data-toc-modified-id="Анализ-3.0.2.1"><span class="toc-item-num">3.0.2.1&nbsp;&nbsp;</span>Анализ</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.0.3"><span class="toc-item-num">3.0.3&nbsp;&nbsp;</span>Вывод</a></span><ul class="toc-item"><li><span><a href="#Постройте-график-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам.-Опишите-результат." data-toc-modified-id="Постройте-график-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам.-Опишите-результат.-3.0.3.1"><span class="toc-item-num">3.0.3.1&nbsp;&nbsp;</span>Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.0.4"><span class="toc-item-num">3.0.4&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Посмотрите,-как-влияют-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков.-Постройте-диаграмму-рассеяния-и-посчитайте-корреляцию-между-отзывами-и-продажами.-Сформулируйте-выводы." data-toc-modified-id="Посмотрите,-как-влияют-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков.-Постройте-диаграмму-рассеяния-и-посчитайте-корреляцию-между-отзывами-и-продажами.-Сформулируйте-выводы.-3.0.5"><span class="toc-item-num">3.0.5&nbsp;&nbsp;</span>Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.</a></span></li><li><span><a href="#Соотношение-с-другими-платформами" data-toc-modified-id="Соотношение-с-другими-платформами-3.0.6"><span class="toc-item-num">3.0.6&nbsp;&nbsp;</span>Соотношение с другими платформами</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.0.7"><span class="toc-item-num">3.0.7&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Распределение-по-жанрам" data-toc-modified-id="Распределение-по-жанрам-3.0.8"><span class="toc-item-num">3.0.8&nbsp;&nbsp;</span>Распределение по жанрам</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.0.9"><span class="toc-item-num">3.0.9&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Составьте-портрет-пользователя-каждого-региона" data-toc-modified-id="Составьте-портрет-пользователя-каждого-региона-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Составьте портрет пользователя каждого региона</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.0.0.1"><span class="toc-item-num">4.0.0.1&nbsp;&nbsp;</span>Вывод:</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.0.0.2"><span class="toc-item-num">4.0.0.2&nbsp;&nbsp;</span>Вывод:</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.0.0.3"><span class="toc-item-num">4.0.0.3&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Проверьте-гипотезы" data-toc-modified-id="Проверьте-гипотезы-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверьте гипотезы</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые" data-toc-modified-id="Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые-5.0.1"><span class="toc-item-num">5.0.1&nbsp;&nbsp;</span>Средние пользовательские рейтинги платформ Xbox One и PC одинаковые</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-5.0.1.1"><span class="toc-item-num">5.0.1.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные" data-toc-modified-id="Средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные-5.0.2"><span class="toc-item-num">5.0.2&nbsp;&nbsp;</span>Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные</a></span><ul class="toc-item"><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-5.0.2.1"><span class="toc-item-num">5.0.2.1&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Стримчик

# %% [markdown]
# # Описание проекта
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
#
# **Цель исследования** :
#  выявить определяющие успешность игры закономерности

# %% [markdown]
# ## Изучение данных из файла

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as st
from pymystem3 import Mystem
m = Mystem()

# %%
df = pd.read_csv('/datasets/games.csv')

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# #### Описание данных
# - Name — название игры
# - Platform — платформа
# - Year_of_Release — год выпуска
# - Genre — жанр игры
# - NA_sales — продажи в Северной Америке (миллионы проданных копий)
# - EU_sales — продажи в Европе (миллионы проданных копий)
# - JP_sales — продажи в Японии (миллионы проданных копий)
# - Other_sales — продажи в других странах (миллионы проданных копий)
# - Critic_Score — оценка критиков (максимум 100)
# - User_Score — оценка пользователей (максимум 10)
# - Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Данные за 2016 год могут быть неполными.

# %%
def all_info(df: pd.DataFrame):
    print("info")
    df.info(verbose=True)
    display('describe' + '\n', df.describe())

# %%
all_info(df)
# Out:
# info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# Name               16713 non-null object
# Platform           16715 non-null object
# Year_of_Release    16446 non-null float64
# Genre              16713 non-null object
# NA_sales           16715 non-null float64
# EU_sales           16715 non-null float64
# JP_sales           16715 non-null float64
# Other_sales        16715 non-null float64
# Critic_Score       8137 non-null float64
# User_Score         10014 non-null object
# Rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB
# 'describe\n'
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# ...

# %% [markdown]
# В названиях колонок видны три нарушения стиля:
# 1. В названиях столбцов - по условиям задачи нужно привести все к нижнему регистру
# 2. Количество значений в столбцах различается. Значит, в данных есть пропущенные значения.
# 3. Year_of_Release заменить тип на целое число, user_score на float.

# %%
#посмотрим пропуски
df.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %%
df.isna().mean() #оценю долю пропусков для дальнейшей чистки данных
# Out:
# Name               0.000120
# Platform           0.000000
# Year_of_Release    0.016093
# Genre              0.000120
# NA_sales           0.000000
# EU_sales           0.000000
# JP_sales           0.000000
# Other_sales        0.000000
# Critic_Score       0.513192
# User_Score         0.400897
# Rating             0.404786
# dtype: float64

# %%
#количество уникальны значений в названиях
df['Name'].nunique()
# Out:
# 11559

# %%
df['Platform'].nunique()
# Out:
# 31

# %%
#посмотреть какие названия платформ
df['Platform'].value_counts()
# Out:
# PS2     2161
# DS      2151
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      430
# PS4      392
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# GB        98
# NES       98
# DC        52
# GEN       29
# NG        12
# WS         6
# SCD        6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %%
df['Genre'].value_counts()
# Out:
# Action          3369
# Sports          2348
# Misc            1750
# Role-Playing    1498
# Shooter         1323
# Adventure       1303
# Racing          1249
# Platform         888
# Simulation       873
# Fighting         849
# Strategy         683
# Puzzle           580
# Name: Genre, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Подготовка данных.
#
# - Замените названия столбцов (приведите к нижнему регистру);
# - Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# - Обработайте пропуски при необходимости:
# - Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
# - Опишите причины, которые могли привести к пропускам;
# - Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать;
# - Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'NA_sales', 'EU_sales',
#        'JP_sales', 'Other_sales', 'Critic_Score', 'User_Score', 'Rating'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower() #поменяла регистр

# %%
df.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %%
df['year_of_release'] = df['year_of_release'].astype('Int64')

# %%
#удалю пропуски в name, так как доля совсем незначительная
df=df.dropna(subset=['name'])

# %%
df[df['year_of_release'].isna()]['name'].values #посмотрю в каких играх пропуски по годам
# Out:
# array(['Madden NFL 2004', 'FIFA Soccer 2004',
#        'LEGO Batman: The Videogame', 'wwe Smackdown vs. Raw 2006',
#        'Space Invaders', 'Rock Band',
#        "Frogger's Adventures: Temple of the Frog",
#        'LEGO Indiana Jones: The Original Adventures', 'Call of Duty 3',
#        'Rock Band', 'Call of Duty: Black Ops', 'Rock Band',
#        'Triple Play 99', 'Adventure', 'LEGO Batman: The Videogame',
#        'Combat', 'LEGO Harry Potter: Years 5-7', 'NASCAR Thunder 2003',
#        'Hitman 2: Silent Assassin', 'Rock Band',
#        'Legacy of Kain: Soul Reaver', 'Donkey Kong Land III',
#        'Air-Sea Battle', 'Suikoden III', 'LEGO Harry Potter: Years 5-7',
#        'Wheel of Fortune', 'Yakuza 4', 'LEGO Harry Potter: Years 5-7',
#        'Namco Museum', 'Rhythm Heaven',
#        'The Lord of the Rings: War in the North', 'Madden NFL 07',
#        'MLB SlugFest 20-03', 'The Lord of the Rings: War in the North',
# ...

# %% [markdown]
# В моем понимании игра может выйти на разных платформах в разный год, поэтому заполнять пропуски в зависимости от других платформ не вижу как. В итоге удалю их, так как доля небольшая от общего количества данных, на анализ повлиять не должно.

# %%
df = df.dropna(subset=['year_of_release'])

# %%
df['critic_score'].value_counts()
# Out:
# 70.0    252
# 71.0    248
# 75.0    240
# 80.0    235
# 73.0    234
#        ...
# 29.0      3
# 20.0      3
# 21.0      1
# 13.0      1
# 17.0      1
# Name: critic_score, Length: 81, dtype: int64

# %%
#посмотрю есть какая-то зависимость рейтинга от продаж
test_critic_score = df.pivot_table(index='critic_score', values = ['na_sales', 'eu_sales', 'jp_sales', 'other_sales' ], aggfunc = [ 'sum'])

# %%
test_critic_score
# Out:
#                   sum
#              eu_sales jp_sales na_sales other_sales
# critic_score
# 13.0             0.01     0.00     0.02        0.01
# 17.0             0.03     0.00     0.06        0.01
# 19.0             0.12     0.00     0.45        0.05
# 20.0             0.45     0.00     1.25        0.17
# 21.0             0.03     0.00     0.08        0.01
# ...               ...      ...      ...         ...
# 94.0            36.24     9.08    68.54       12.65
# 95.0            26.00     4.49    55.89       18.96
# 96.0            20.94     7.11    39.02        5.51
# 97.0            36.25     4.09    50.68       11.11
# 98.0             8.17     0.94    14.57        2.84
#
# [81 rows x 4 columns]

# %% [markdown]
# По всей видимости мало продаж = низкий рейтинг. Но заполнять 0 или медианнами не выход, так как можем получить неточную картину при анализе.  Оставлю пока как есть.

# %%
df['user_score'].value_counts()
# Out:
# tbd    2376
# 7.8     322
# 8       285
# 8.2     276
# 8.3     252
#        ...
# 0.3       2
# 0.6       2
# 1.5       2
# 9.7       1
# 0         1
# Name: user_score, Length: 96, dtype: int64

# %% [markdown]
# tbd = To Be Determined, то есть "Будет определено". По всей видимости игра настолько неординарная, что рейтинг пользователи не смогли поставить.

# %%
df[df['user_score']=='tbd']
# Out:
#                                  name platform  year_of_release       genre  \
# 119                     Zumba Fitness      Wii             2010      Sports
# 301    Namco Museum: 50th Anniversary      PS2             2005        Misc
# 520                   Zumba Fitness 2      Wii             2011      Sports
# 645                      uDraw Studio      Wii             2010        Misc
# 718                   Just Dance Kids      Wii             2010        Misc
# ...                               ...      ...              ...         ...
# 16695                 Planet Monsters      GBA             2001      Action
# 16697                Bust-A-Move 3000       GC             2003      Puzzle
# 16698                Mega Brain Boost       DS             2008      Puzzle
# 16704                        Plushees       DS             2008  Simulation
# 16706   Men in Black II: Alien Escape       GC             2003     Shooter
#
# ...

# %%
df[df['user_score'] == 'tbd']['year_of_release'].unique() #посмотрим есть ли зависимость по годам
# Out:
# <IntegerArray>
# [2010, 2005, 2011, 2009, 2004, 1999, 2001, 2008, 2007, 2003, 2000, 2006, 2002,
#  2015, 2014, 2012, 2013, 2016, 1997]
# Length: 19, dtype: Int64

# %% [markdown]
# на первый взгляд не так чтобы много продаж было по tbd, по данному столбцу надо поменять тип данных, поэтому tbd заменю на nan (не определено = нет значений)

# %%
df.loc[df['user_score'] == 'tbd', 'user_score'] = float('nan')

# %%
df['user_score'] = df['user_score'].astype(float)

# %%
df['user_score'].value_counts()
# Out:
# 7.8    322
# 8.0    285
# 8.2    276
# 8.3    252
# 7.5    249
#       ...
# 9.6      2
# 0.6      2
# 1.9      2
# 9.7      1
# 0.0      1
# Name: user_score, Length: 95, dtype: int64

# %%
df['user_score'].unique()
# Out:
# array([8. , nan, 8.3, 8.5, 6.6, 8.4, 8.6, 7.7, 6.3, 7.4, 8.2, 9. , 7.9,
#        8.1, 8.7, 7.1, 3.4, 5.3, 4.8, 3.2, 8.9, 6.4, 7.8, 7.5, 2.6, 7.2,
#        9.2, 7. , 7.3, 4.3, 7.6, 5.7, 5. , 9.1, 6.5, 8.8, 6.9, 9.4, 6.8,
#        6.1, 6.7, 5.4, 4. , 4.9, 4.5, 9.3, 6.2, 4.2, 6. , 3.7, 4.1, 5.8,
#        5.6, 5.5, 4.4, 4.6, 5.9, 3.9, 3.1, 2.9, 5.2, 3.3, 4.7, 5.1, 3.5,
#        2.5, 1.9, 3. , 2.7, 2.2, 2. , 9.5, 2.1, 3.6, 2.8, 1.8, 3.8, 0. ,
#        1.6, 9.6, 2.4, 1.7, 1.1, 0.3, 1.5, 0.7, 1.2, 2.3, 0.5, 1.3, 0.2,
#        0.6, 1.4, 0.9, 1. , 9.7])

# %%
df[['critic_score','user_score','na_sales','eu_sales','jp_sales','other_sales']].describe()
# Out:
#        critic_score   user_score      na_sales      eu_sales      jp_sales  \
# count   7983.000000  7463.000000  16444.000000  16444.000000  16444.000000
# mean      68.994363     7.126330      0.264012      0.145930      0.078487
# std       13.920060     1.499447      0.818378      0.506716      0.311100
# min       13.000000     0.000000      0.000000      0.000000      0.000000
# 25%       60.000000     6.400000      0.000000      0.000000      0.000000
# 50%       71.000000     7.500000      0.080000      0.020000      0.000000
# 75%       79.000000     8.200000      0.240000      0.110000      0.040000
# max       98.000000     9.700000     41.360000     28.960000     10.220000
#
#         other_sales
# count  16444.000000
# mean       0.047594
# std        0.188005
# min        0.000000
# 25%        0.000000
# 50%        0.010000
# 75%        0.030000
# max       10.570000

# %%
df.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score         8981
# rating             6676
# dtype: int64

# %%
rating_group = df.groupby('rating').agg({'name':'count'})
rating_group
# Out:
#         name
# rating
# AO         1
# E       3921
# E10+    1393
# EC         8
# K-A        3
# M       1536
# RP         1
# T       2905

# %%
df.duplicated().sum() #дубликатов нет
# Out:
# 0

# %%
df.loc[16713]
# Out:
# name               Spirits & Spells
# platform                        GBA
# year_of_release                2003
# genre                      Platform
# na_sales                       0.01
# eu_sales                          0
# jp_sales                          0
# other_sales                       0
# critic_score                    NaN
# user_score                      NaN
# rating                          NaN
# Name: 16713, dtype: object

# %%
df[df['name']=='Spirits & Spells'] #совпадений не нашла, даже если они и есть, возможно не смогли присвоить определенному возрасту рейтинг
# Out:
#                    name platform  year_of_release     genre  na_sales  \
# 15771  Spirits & Spells       GC             2003  Platform      0.01
# 16713  Spirits & Spells      GBA             2003  Platform      0.01
#
#        eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 15771       0.0       0.0          0.0           NaN         NaN    NaN
# 16713       0.0       0.0          0.0           NaN         NaN    NaN

# %%
df['rating'] = df['rating'].fillna('не определен')

# %% [markdown]
# рейтинг присваивается скорее всего от названия игры по возрасту, значит можно было бы попробовать заполнить пропуски по аналогии, но рейтинг мог и не присвоиться,  так как игра не вошла в категорию (не нашла пример, чтобы у названия на одной из платформ был рейтинг, у бругой не было). Крупнейшая негосударственная организация (ESRB), присуждающая рейтинги играм была основана в 1994 году. Соответственно, далеко не всем играм, выпущенным до этого года, присуждался рейтинг. Заменю пока пропуски на рейтинг не определен (так как без опыта в игровой сфере лучше выбрать компромиссный вариант).

# %%
df.head(10)
# Out:
#                         name platform  year_of_release         genre  \
# 0                 Wii Sports      Wii             2006        Sports
# 1          Super Mario Bros.      NES             1985      Platform
# 2             Mario Kart Wii      Wii             2008        Racing
# 3          Wii Sports Resort      Wii             2009        Sports
# 4   Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# 5                     Tetris       GB             1989        Puzzle
# 6      New Super Mario Bros.       DS             2006      Platform
# 7                   Wii Play      Wii             2006          Misc
# 8  New Super Mario Bros. Wii      Wii             2009      Platform
# 9                  Duck Hunt      NES             1984       Shooter
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 0     41.36     28.96      3.77         8.45          76.0         8.0
# ...

# %%
#Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.
df['all_sales']= df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df ['other_sales']

# %% [markdown]
# ### Вывод
# Обнаружны пропуски и некорректные типы данных, которые заменила. Пропуски не заменяла, так как логика замены не прозрачная, а все варианты, которые нашла, могут повлиять на стат.анализ. Часть пропусков просто удалила, так как доля незначительная. Добавлен столбец с суммой продаж.

# %% [markdown]
# ## Исследовательский анализ данных
# - Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# - Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# - Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
# Не учитывайте в работе данные за предыдущие годы.
# - Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# - Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
# - Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. - Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# - Соотнесите выводы с продажами игр на других платформах.
# - Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %% [markdown]
#  ##### Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
game_year = df.groupby('year_of_release')['name'].count().reset_index()
game_year.columns = ['year', 'count']
game_year
# Out:
#     year  count
# 0   1980      9
# 1   1981     46
# 2   1982     36
# 3   1983     17
# 4   1984     14
# 5   1985     14
# 6   1986     21
# 7   1987     16
# 8   1988     15
# 9   1989     17
# 10  1990     16
# 11  1991     41
# 12  1992     43
# 13  1993     60
# 14  1994    121
# 15  1995    219
# 16  1996    263
# 17  1997    289
# 18  1998    379
# 19  1999    338
# 20  2000    350
# 21  2001    482
# 22  2002    829
# 23  2003    775
# 24  2004    762
# 25  2005    939
# 26  2006   1006
# 27  2007   1197
# 28  2008   1427
# 29  2009   1426
# 30  2010   1255
# 31  2011   1136
# 32  2012    653
# 33  2013    544
# 34  2014    581
# 35  2015    606
# 36  2016    502

# %%
plt.figure(figsize=(14, 5))
plt.bar(game_year['year'], game_year ['count'], alpha=0.9, width=0.8)
plt.xlabel('Год')
plt.ylabel('Кол-во игр')
plt.title('Кол-во релизов по годам')
plt.show()

# %%
#вариант 2
game_year_pivot =  df.pivot_table(index='year_of_release', values='name', aggfunc= 'count')
game_year_pivot.plot()
plt.xlabel('год выхода')
plt.title('Количество игр в зависимости от года', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Количество игр в зависимости от года')

# %% [markdown]
# #### Вывод
# До 1995 года количество игр выпускалось мало. Видно, что в период после 1995 в релизах игр наступает увеличение количества, игры становятся популярными и более доступными для населения (возможно). С   2010 (в первом варианте видно лучше) наступает снижение в количестве игр,  релизы падают в 2 раза и далее идут примерно на 1 уровне (Предположу что дело в качестве,  требования к играм выросли - требования к графике, проработке деталей. Все это повлияло на стоимость и скорость разработки, соответственно количество снизилось. А вот бюджет скорее всего увеличился.)

# %% [markdown]
# ##### Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.¶
# Не учитывайте в работе данные за предыдущие годы. Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.

# %%
platform_sales = df.groupby('platform')['all_sales'].sum().reset_index().sort_values(by = 'all_sales', ascending = False)
platform_sales.columns = ['platform', 'sales']
platform_sales
# Out:
#    platform    sales
# 16      PS2  1233.56
# 28     X360   961.24
# 17      PS3   931.34
# 26      Wii   891.18
# 4        DS   802.78
# 15       PS   727.58
# 18      PS4   314.14
# 6       GBA   312.88
# 19      PSP   289.53
# 2       3DS   257.81
# 13       PC   255.76
# 5        GB   254.43
# 29       XB   251.57
# 11      NES   251.05
# 10      N64   218.01
# 23     SNES   200.04
# 7        GC   196.73
# 30     XOne   159.32
# 0      2600    86.48
# 27     WiiU    82.19
# 20      PSV    53.81
# 21      SAT    33.59
# 8       GEN    28.35
# 3        DC    15.95
# 22      SCD     1.86
# 12       NG     1.44
# 25       WS     1.42
# 24     TG16     0.16
# 1       3DO     0.10
# 9        GG     0.04
# 14     PCFX     0.03

# %%
plt.figure(figsize=(14, 5))
plt.bar(platform_sales['platform'], platform_sales ['sales'], alpha=0.9, width=0.8)
plt.xlabel('Платформа')
plt.ylabel('Продажи')
plt.title('Кол-во продаж по платформам')
plt.show()

# %% [markdown]
# Cамые популярные игровые платформы за весь период это PS2, X360, PS3, WII, DS, PS

# %%
#топ платформ
platform_top = df.groupby('platform')['all_sales'].sum().reset_index().sort_values(by = 'all_sales', ascending = False)
platform_top.columns = ['platform', 'sales']
platform_top.head(6)
# Out:
#    platform    sales
# 16      PS2  1233.56
# 28     X360   961.24
# 17      PS3   931.34
# 26      Wii   891.18
# 4        DS   802.78
# 15       PS   727.58

# %%
platform_top = platform_sales.loc[:15,'platform'].values
platform_top
# Out:
# array(['PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS'], dtype=object)

# %%
#общие продажи топ платформ
platform_sales_year = df.query('platform in @platform_top').groupby('year_of_release')['all_sales'].sum()
platform_sales_year
# Out:
# year_of_release
# 1985      0.02
# 1994      6.03
# 1995     35.96
# 1996     94.70
# 1997    136.17
# 1998    169.49
# 1999    144.53
# 2000    135.54
# 2001    202.02
# 2002    212.05
# 2003    186.38
# 2004    229.08
# 2005    299.05
# 2006    432.96
# 2007    544.30
# 2008    624.31
# 2009    604.13
# 2010    530.81
# 2011    386.90
# 2012    239.82
# 2013    211.96
# 2014     86.25
# 2015     29.92
# 2016      5.30
# Name: all_sales, dtype: float64

# %%
#продажи топ в разрезе платформ
platform_sales_year = df.groupby(['platform', 'year_of_release']).agg({'all_sales': 'sum'}).query('platform in @platform_top').reset_index()
platform_sales_year
# Out:
#    platform  year_of_release  all_sales
# 0        DS             1985       0.02
# 1        DS             2004      17.27
# 2        DS             2005     130.14
# 3        DS             2006     119.81
# 4        DS             2007     146.94
# ..      ...              ...        ...
# 62     X360             2012      99.74
# 63     X360             2013      88.58
# 64     X360             2014      34.74
# 65     X360             2015      11.96
# 66     X360             2016       1.52
#
# [67 rows x 3 columns]

# %%
#продажи топ в разрезе платформ
platform_sales_year_pivot = df.pivot_table(index = ['platform', 'year_of_release'], values = 'all_sales', aggfunc = 'sum' ).query('platform in @platform_top').reset_index()
platform_sales_year_pivot
# Out:
#    platform  year_of_release  all_sales
# 0        DS             1985       0.02
# 1        DS             2004      17.27
# 2        DS             2005     130.14
# 3        DS             2006     119.81
# 4        DS             2007     146.94
# ..      ...              ...        ...
# 62     X360             2012      99.74
# 63     X360             2013      88.58
# 64     X360             2014      34.74
# 65     X360             2015      11.96
# 66     X360             2016       1.52
#
# [67 rows x 3 columns]

# %%
plt.figure(figsize=(15, 6))
sns.lineplot(data = platform_sales_year_pivot, y=platform_sales_year_pivot['all_sales'], x = platform_sales_year_pivot['year_of_release'], hue= platform_sales_year_pivot['platform'], style= platform_sales_year_pivot['platform'], dashes=False  )
plt.title('Объём продаж на разных платформах по годам')
plt.xlabel('Год')    
plt.ylabel('Объём продаж за год')
plt.legend()

# %%
#вариант 2 (для тренировки)
platform_sales_year.pivot_table(index =  'year_of_release', columns = 'platform', values = 'all_sales', aggfunc = 'sum' ).plot()

# %%
#посмотрим как распределились продажи в топ платвормах на пиковые года
platform_sales_year.groupby('platform').mean()
# Out:
#           year_of_release   all_sales
# platform
# DS            2006.363636   72.980000
# PS            1998.500000   72.758000
# PS2           2005.500000  102.796667
# PS3           2011.000000   84.667273
# Wii           2011.000000   81.016364
# X360          2010.500000   80.103333

# %%
#найдем актуальный период - делится на 2, так как половину занимает спад
platform_sales_year.reset_index().groupby('platform').agg({'year_of_release': 'nunique'}).mean()/2
# Out:
# year_of_release    5.583333
# dtype: float64

# %% [markdown]
# #### Вывод
# - Практически все игровые платформы в среднем существуют примерно 10 лет.
# - Cамые продаваемые это PS (Sony Play Station?) и X360,  у Wii (Nintendo?) резкий взлет и провал
# - Самый пик наступает примерно через 5 лет после выхода

# %% [markdown]
# ##### Анализ
# для дальнейшего анализа был определен актуальный период в 5 лет, поэтому исследовать буду данные с 2010 года, прошлые года также странно брать для анализа, так как данные в игровой индустрии быстро становятся неактуальными

# %%
new_year = df[df['year_of_release'] >= 2010]
new_year
# Out:
#                                  name platform  year_of_release         genre  \
# 14                 Kinect Adventures!     X360             2010          Misc
# 16                 Grand Theft Auto V      PS3             2013        Action
# 23                 Grand Theft Auto V     X360             2013        Action
# 27        Pokemon Black/Pokemon White       DS             2010  Role-Playing
# 29     Call of Duty: Modern Warfare 3     X360             2011       Shooter
# ...                               ...      ...              ...           ...
# 16703                Strawberry Nauts      PSV             2016     Adventure
# 16707                Aiyoku no Eustia      PSV             2014          Misc
# 16710   Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16712         Haitaka no Psychedelica      PSV             2016     Adventure
# 16714             Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
#найдем новый топ платформ
platform_sales_new_top = new_year.groupby('platform')['all_sales'].sum().sort_values(ascending = False).reset_index()
platform_sales_new_top
# Out:
#    platform  all_sales
# 0       PS3     587.74
# 1      X360     550.41
# 2       PS4     314.14
# 3       3DS     257.81
# 4       Wii     222.97
# 5      XOne     159.32
# 6        DS     123.75
# 7        PC     121.96
# 8      WiiU      82.19
# 9       PSP      64.05
# 10      PSV      53.81
# 11      PS2       6.09

# %%
#топ 7 платформ
platform_top_new = platform_sales_new_top.loc[:10,'platform'].values
platform_top_new
# Out:
# array(['PS3', 'X360', 'PS4', '3DS', 'Wii', 'XOne', 'DS', 'PC', 'WiiU',
#        'PSP', 'PSV'], dtype=object)

# %%
#продажи топ в разрезе платформ
platform_sales_new = new_year.groupby(['platform', 'year_of_release']).agg({'all_sales': 'sum'}).query('platform in @platform_top_new').reset_index()
platform_sales_new
# Out:
#    platform  year_of_release  all_sales
# 0       3DS             2011      63.20
# 1       3DS             2012      51.36
# 2       3DS             2013      56.57
# 3       3DS             2014      43.76
# 4       3DS             2015      27.78
# ..      ...              ...        ...
# 58     X360             2016       1.52
# 59     XOne             2013      18.96
# 60     XOne             2014      54.07
# 61     XOne             2015      60.14
# 62     XOne             2016      26.15
#
# [63 rows x 3 columns]

# %%
platform_sales_new.pivot_table(index =  'year_of_release', columns = 'platform', values = 'all_sales', aggfunc = 'sum' ).plot()

# %% [markdown]
# #### Вывод
# - Многие платформы топ видно, что подходят к концу цикла
# - Cамые перспективные - Wii и XOne, так как появились недавно и еще есть запас активного цикла
# - я увеличила в итоге количество топ платформ (изначально брала 6), и вижу что еще развивается WiiU достаточно стабильно,  PS (как я понимаю это Sony, они всегда актуальны), PSV.
# По всей видимости нужно смотреть не только по продажам, так как новые платформы выстреливают и продажи большие, но есть ряд платформ со стабильным циклом, которые однозначно надо включать в план

# %% [markdown]
# ##### Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.

# %%
top10 = platform_sales_new_top.head(10)

# %%
top10
# Out:
#   platform  all_sales
# 0      PS3     587.74
# 1     X360     550.41
# 2      PS4     314.14
# 3      3DS     257.81
# 4      Wii     222.97
# 5     XOne     159.32
# 6       DS     123.75
# 7       PC     121.96
# 8     WiiU      82.19
# 9      PSP      64.05

# %%
game_top = new_year[new_year['platform'].isin(platform_top_new)]
game_top
# Out:
#                                  name platform  year_of_release         genre  \
# 14                 Kinect Adventures!     X360             2010          Misc
# 16                 Grand Theft Auto V      PS3             2013        Action
# 23                 Grand Theft Auto V     X360             2013        Action
# 27        Pokemon Black/Pokemon White       DS             2010  Role-Playing
# 29     Call of Duty: Modern Warfare 3     X360             2011       Shooter
# ...                               ...      ...              ...           ...
# 16703                Strawberry Nauts      PSV             2016     Adventure
# 16707                Aiyoku no Eustia      PSV             2014          Misc
# 16710   Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16712         Haitaka no Psychedelica      PSV             2016     Adventure
# 16714             Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=game_top, x='platform', y='all_sales')
plt.title('Ящик с усами', fontsize=15)
plt.xlabel('Платформа', fontsize=12)
plt.ylabel('Глобальные продажи',fontsize=12)
plt.yscale('log')

# %% [markdown]
# по графику видно, что есть выбросы, скорректирую сумму удалив их и график будет нагляднее

# %%
game_top = game_top[game_top['all_sales']<1.75]

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=game_top, x='platform', y='all_sales')
plt.title('Ящик с усами', fontsize=15)
plt.xlabel('Платформа', fontsize=12)
plt.ylabel('Глобальные продажи',fontsize=12)
plt.yscale('log')

# %%
#КОД РЕВЬЮЕРА
#добавим ограничение по оси Y
plt.figure(figsize=(15,5))
sns.boxplot(data = game_top, x='platform', y='all_sales')
plt.ylim([0,1])

#а теперь твой исходный
fig, ax = plt.subplots(figsize =(15,5))
sns.boxplot(x = 'platform', 
            y = 'all_sales',
            data = game_top[game_top['all_sales']<1.75],ax=ax)

# %% [markdown]
# #### Вывод
# Можно сказать что продажи на популярных платформах похожи, среднее у некоторых на уровне 0.2, у других около 0.1. Хорошие продажи у PS3, X360, WIIU. Хуже всех PSV, PSP

# %% [markdown]
# #### Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# рассматривать будем X360 (так как она в топе и я ее знаю)

# %%
x_platform = df.query('platform=="X360"')[['all_sales', 'critic_score', 'user_score']].reset_index(drop=True)
x_platform
# Out:
#       all_sales  critic_score  user_score
# 0         21.82          61.0         6.3
# 1         16.27          97.0         8.1
# 2         14.73          88.0         3.4
# 3         14.62          87.0         6.3
# 4         13.68          83.0         4.8
# ...         ...           ...         ...
# 1227       0.01          49.0         2.1
# 1228       0.01           NaN         NaN
# 1229       0.01           NaN         NaN
# 1230       0.01           NaN         5.1
# 1231       0.01           NaN         NaN
#
# [1232 rows x 3 columns]

# %%
x_platform.corr() #зависимость продаж от рейтинга критиков 0.39, от пользователей слабее  - 0.1
# Out:
#               all_sales  critic_score  user_score
# all_sales      1.000000      0.392866    0.114187
# critic_score   0.392866      1.000000    0.625020
# user_score     0.114187      0.625020    1.000000

# %%
x_platform.plot(x='critic_score',y='all_sales',kind='scatter',figsize=(15,5), alpha=0.5)
plt.title('Зависимость Продаж от рейтинга критиков');

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='user_score', y='all_sales', data=x_platform)
plt.title('Зависимость Продаж от рейтинга пользователей')
# Out:
# Text(0.5, 1.0, 'Зависимость Продаж от рейтинга пользователей')

# %% [markdown]
# По платформе X360: зависимость продаж от отзывов критиков  средняя (коэффициент 0,39) - чем выше оценка, тем выше продажи. Зависимость продаж от отзывов пользователей 0,1 - т/е связь отсутсвует.  Учитывая как много пропусков в рейтингах, предположу, что в игровой индустрии более значимыми являются какие-то другие параметры - может доля повторных клиентов, количество игроков, доп покупки.

# %% [markdown]
# <div class="alert alert-warning">
#  Значения коэффициента по модулю меньше 0.2 оценивают как вообще отсутствие связи. В данных всегда есть выбросы, неточности и тд, поэтому коэффициент в реальной жизни никогда не принимает значение 0 или 1. Так что отзывы пользователей вообще не оказывают влияния на продажи
# </div>

# %% [markdown]
# #### Соотношение с другими платформами

# %%
ratio_platform = game_top.query('platform in @platform_top_new')[['platform', 'all_sales', 'critic_score', 'user_score']].reset_index(drop=True)
ratio_platform
# Out:
#      platform  all_sales  critic_score  user_score
# 0         PS4       1.74          82.0         4.9
# 1         PS3       1.74           NaN         NaN
# 2         PS3       1.74           NaN         5.1
# 3        X360       1.74          55.0         3.5
# 4         PS3       1.74          78.0         8.3
# ...       ...        ...           ...         ...
# 4926      PSV       0.01           NaN         NaN
# 4927      PSV       0.01           NaN         NaN
# 4928      PS3       0.01           NaN         NaN
# 4929      PSV       0.01           NaN         NaN
# 4930      PSV       0.01           NaN         NaN
#
# [4931 rows x 4 columns]

# %%
ratio_platform.corr()
# Out:
#               all_sales  critic_score  user_score
# all_sales      1.000000      0.333722    0.101546
# critic_score   0.333722      1.000000    0.574834
# user_score     0.101546      0.574834    1.000000

# %%
pd.plotting.scatter_matrix(ratio_platform, figsize=(9,9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5191fd4290>,
# ...
#       dtype=object)

# %%
#вариант 2 сделать таблицу корр сразу - тренировка для себя
ratio_platform1 = game_top.groupby('platform')[ 'all_sales', 'critic_score', 'user_score'].corr()
ratio_platform1
# Out:
#                        all_sales  critic_score  user_score
# platform
# 3DS      all_sales      1.000000      0.278100    0.160290
#          critic_score   0.278100      1.000000    0.720545
#          user_score     0.160290      0.720545    1.000000
# DS       all_sales      1.000000      0.267497    0.281166
#          critic_score   0.267497      1.000000    0.619786
#          user_score     0.281166      0.619786    1.000000
# PC       all_sales      1.000000      0.352830    0.017823
#          critic_score   0.352830      1.000000    0.489290
#          user_score     0.017823      0.489290    1.000000
# PS3      all_sales      1.000000      0.528688    0.217255
#          critic_score   0.528688      1.000000    0.621107
#          user_score     0.217255      0.621107    1.000000
# PS4      all_sales      1.000000      0.272624    0.011444
#          critic_score   0.272624      1.000000    0.628491
#          user_score     0.011444      0.628491    1.000000
# ...

# %%
pd.plotting.scatter_matrix(ratio_platform, figsize=(9,9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f51835db990>,
# ...
#       dtype=object)

# %%
#зависимость всех платформ на одном графике (нагляднее чем в матрице)
import seaborn
plt.figure(figsize=(16, 9))
plt.grid()
plt.title('Зависимости продаж от отзывов Критиков на разных платформах')
seaborn.scatterplot(x= ratio_platform['critic_score'], y= ratio_platform['all_sales'], hue = ratio_platform['platform'])

# %%
#зависимость всех платформ на одном графике
import seaborn
plt.figure(figsize=(16, 9))
plt.grid()
plt.title('Зависимости продаж от отзывов пользователей на разных платформах')
seaborn.scatterplot(x= ratio_platform['user_score'], y= ratio_platform['all_sales'], hue = ratio_platform['platform'])

# %% [markdown]
# #### Вывод
# Корреляция одинаковая почти для всех платформ. Зависимость продаж пропорцианальная - от отзывов критиков слабая но ближе к средней, а от отзывов пользователей слабее, чем критиков. При этом очевидно, что покупатели прислушиваются больше к критикам,  чем к оценкам других пользователей

# %% [markdown]
# #### Распределение по жанрам
# Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
#посмотрим распределение по жанрам за актуальный выбранный ранее период
genres = new_year.groupby('genre')['name'].count().sort_values(ascending=False).reset_index()
genres
# Out:
#            genre  name
# 0         Action  1495
# 1           Misc   576
# 2         Sports   575
# 3   Role-Playing   568
# 4      Adventure   563
# 5        Shooter   410
# 6         Racing   237
# 7     Simulation   217
# 8       Fighting   199
# 9       Strategy   170
# 10      Platform   153
# 11        Puzzle   114

# %%
#распределение жанров по продажам
genre_sales = new_year.groupby('genre')['all_sales'].sum().sort_values(ascending=False).reset_index()
genre_sales
# Out:
#            genre  all_sales
# 0         Action     673.09
# 1        Shooter     479.74
# 2         Sports     328.39
# 3   Role-Playing     315.28
# 4           Misc     234.56
# 5         Racing     122.68
# 6       Platform     119.72
# 7       Fighting      81.59
# 8     Simulation      71.75
# 9      Adventure      61.00
# 10      Strategy      35.84
# 11        Puzzle      20.60

# %%
fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot()
plt.title('Распределение игр по жанрам ',fontsize=12)
sns.barplot(data=genres, x='genre', y='name', label='игры')
ax.plot(genre_sales['genre'], genre_sales['all_sales'], color='tab:blue', label='продажи')

plt.xlabel('Жанры игр',fontsize=9)
plt.ylabel('Распредение',fontsize=9)
plt.legend()
plt.show()

# %%
genre_sales_count = new_year.groupby('genre').agg({'all_sales': ['sum', 'count', 'mean']})
genre_sales_count.columns = ['sum', 'count', 'mean']
genre_sales_count
# Out:
#                  sum  count      mean
# genre
# Action        673.09   1495  0.450227
# Adventure      61.00    563  0.108348
# Fighting       81.59    199  0.410000
# Misc          234.56    576  0.407222
# Platform      119.72    153  0.782484
# Puzzle         20.60    114  0.180702
# Racing        122.68    237  0.517637
# Role-Playing  315.28    568  0.555070
# Shooter       479.74    410  1.170098
# Simulation     71.75    217  0.330645
# Sports        328.39    575  0.571113
# Strategy       35.84    170  0.210824

# %% [markdown]
# #### Вывод
# Общее распределение игр по жанрам - Action, Misc, Sports, Role-Playing, Adventure (значения близко друг с другом).
#
# Меньше всего приходится на Puzzle.
#
# В продажах по жанрам в лидерах опять Action, Sports, и на 3 месте уже Shooter; хуже всего Strategy и  Puzzle.

# %%
fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot()
plt.title('Распределение средних показателей игр по жанрам ',fontsize=12)
ax.plot( genre_sales_count['mean'], color='tab:blue', label='продажи')

plt.xlabel('Жанры игр',fontsize=9)
plt.ylabel('Средние',fontsize=9)
plt.legend()
plt.show()

# %% [markdown]
# ## Составьте портрет пользователя каждого региона
# - Определите для пользователя каждого региона (NA, EU, JP):
# - Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# - Самые популярные жанры (топ-5). Поясните разницу.
# - Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
#найдем новый топ платформ в na
platform_na_top = new_year.groupby('platform')['na_sales'].sum().sort_values(ascending = False).reset_index()
platform_na_top.columns = ['platform','na_sales']
platform_na_top.head(5)
# Out:
#   platform  na_sales
# 0     X360    334.18
# 1      PS3    229.25
# 2      Wii    121.20
# 3      PS4    108.74
# 4     XOne     93.12

# %%
platform_na_top = platform_na_top.head(5)
platform_na_top
# Out:
#   platform  na_sales
# 0     X360    334.18
# 1      PS3    229.25
# 2      Wii    121.20
# 3      PS4    108.74
# 4     XOne     93.12

# %% [markdown]
# platform_na_top['count'] = (platform_na_top['na_sales'])/(new_year['na_sales'].sum())
# platform_na_top.head(5)

# %%
platform_eu_top = new_year.groupby('platform')['eu_sales'].sum().sort_values(ascending = False).reset_index()
platform_eu_top.columns = ['platform','eu_sales']
platform_eu_top.head(5)
platform_eu_top = platform_eu_top.head(5)
platform_eu_top
# Out:
#   platform  eu_sales
# 0      PS3    213.60
# 1     X360    163.41
# 2      PS4    141.09
# 3       PC     68.82
# 4      Wii     65.91

# %%
platform_jp_top = new_year.groupby('platform')['jp_sales'].sum().sort_values(ascending = False).reset_index()
platform_jp_top.columns = ['platform','jp_sales']
platform_jp_top.head(5)
platform_jp_top = platform_jp_top.head(5)
platform_jp_top
# Out:
#   platform  jp_sales
# 0      3DS    100.62
# 1      PS3     59.26
# 2      PSP     42.20
# 3       DS     27.90
# 4      PSV     21.84

# %%
platform_region_top = pd.concat([platform_na_top, platform_eu_top,platform_jp_top ], sort=False)
platform_region_top
# Out:
#   platform  na_sales  eu_sales  jp_sales
# 0     X360    334.18       NaN       NaN
# 1      PS3    229.25       NaN       NaN
# 2      Wii    121.20       NaN       NaN
# 3      PS4    108.74       NaN       NaN
# 4     XOne     93.12       NaN       NaN
# 0      PS3       NaN    213.60       NaN
# 1     X360       NaN    163.41       NaN
# 2      PS4       NaN    141.09       NaN
# 3       PC       NaN     68.82       NaN
# 4      Wii       NaN     65.91       NaN
# 0      3DS       NaN       NaN    100.62
# 1      PS3       NaN       NaN     59.26
# 2      PSP       NaN       NaN     42.20
# 3       DS       NaN       NaN     27.90
# 4      PSV       NaN       NaN     21.84

# %%
platform_all_top = platform_na_top.merge(platform_eu_top, how='outer')
platform_all_top
# Out:
#   platform  na_sales  eu_sales
# 0     X360    334.18    163.41
# 1      PS3    229.25    213.60
# 2      Wii    121.20     65.91
# 3      PS4    108.74    141.09
# 4     XOne     93.12       NaN
# 5       PC       NaN     68.82

# %%
#вариант 2 объединения
platform_all_top = platform_all_top.merge(platform_jp_top, how='outer')
platform_all_top
# Out:
#   platform  na_sales  eu_sales  jp_sales
# 0     X360    334.18    163.41       NaN
# 1      PS3    229.25    213.60     59.26
# 2      Wii    121.20     65.91       NaN
# 3      PS4    108.74    141.09       NaN
# 4     XOne     93.12       NaN       NaN
# 5       PC       NaN     68.82       NaN
# 6      3DS       NaN       NaN    100.62
# 7      PSP       NaN       NaN     42.20
# 8       DS       NaN       NaN     27.90
# 9      PSV       NaN       NaN     21.84

# %%
plt.title('Распределение продаж по региону na ',fontsize=12)
sns.barplot(data=platform_all_top, x='platform', y = 'na_sales', label = 'na_sales')
plt.xlabel('Платформы',fontsize=9)
plt.ylabel('Продажи',fontsize=9)
plt.legend()
plt.show()

# %%
plt.title('Распределение продаж по регионам ',fontsize=12)
sns.barplot(data=platform_all_top, x='platform', y = 'eu_sales', label='eu_sales')
plt.xlabel('Платформы',fontsize=9)
plt.ylabel('Продажи',fontsize=9)
plt.legend()
plt.show()

# %%
plt.title('Распределение продаж по регионам ',fontsize=12)
sns.barplot(data=platform_all_top, x='platform', y = 'jp_sales', label='jp_sales')
plt.xlabel('Платформы',fontsize=9)
plt.ylabel('Продажи',fontsize=9)
plt.legend()
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(16, 6))
fig.autofmt_xdate()
ax1 = sns.barplot(data=platform_all_top, x='platform', y = 'jp_sales', label='jp_sales', ax=ax1)
ax2 = sns.barplot(data=platform_all_top, x='platform', y = 'eu_sales', label = 'eu_sales', ax = ax2)
ax3 = sns.barplot(data=platform_all_top, x='platform', y = 'na_sales', label = 'na_sales', ax = ax3)

# %% [markdown]
# ##### Вывод:
# Лидеры продаж во всех регионах разные: Америка - X360, Европа - PS3 и Япония - 3DS. Платформы в америке и европе похожи,  а в японии совсем другая картина: тут более популярны платформы 3DS, PSP, DS, PSV. Платформа PS3 популярна во всех регионах.

# %%
genre_na_top = new_year.groupby('genre')['na_sales'].sum().sort_values(ascending = False).reset_index()
genre_na_top.columns = ['genre','na_sales']
genre_na_top.head(5)
genre_na_top = genre_na_top.head(5)
genre_na_top
# Out:
#           genre  na_sales
# 0        Action    290.64
# 1       Shooter    237.47
# 2        Sports    156.81
# 3          Misc    123.80
# 4  Role-Playing    112.05

# %%
genre_eu_top = new_year.groupby('genre')['eu_sales'].sum().sort_values(ascending = False).reset_index()
genre_eu_top.columns = ['genre','eu_sales']
genre_eu_top.head(5)
genre_eu_top = genre_eu_top.head(5)
genre_eu_top
# Out:
#           genre  eu_sales
# 0        Action    233.63
# 1       Shooter    171.45
# 2        Sports    116.84
# 3  Role-Playing     75.48
# 4          Misc     66.09

# %%
genre_jp_top = new_year.groupby('genre')['jp_sales'].sum().sort_values(ascending = False).reset_index()
genre_jp_top.columns = ['genre','jp_sales']
genre_jp_top.head(5)
genre_jp_top = genre_jp_top.head(5)
genre_jp_top
# Out:
#           genre  jp_sales
# 0  Role-Playing    103.54
# 1        Action     72.20
# 2          Misc     24.29
# 3      Platform     15.81
# 4     Adventure     15.67

# %%
genre_all_top = genre_na_top.merge(genre_eu_top, how='outer')
genre_all_top
# Out:
#           genre  na_sales  eu_sales
# 0        Action    290.64    233.63
# 1       Shooter    237.47    171.45
# 2        Sports    156.81    116.84
# 3          Misc    123.80     66.09
# 4  Role-Playing    112.05     75.48

# %%
genre_all_top = genre_all_top.merge(genre_jp_top, how='outer')
genre_all_top
# Out:
#           genre  na_sales  eu_sales  jp_sales
# 0        Action    290.64    233.63     72.20
# 1       Shooter    237.47    171.45       NaN
# 2        Sports    156.81    116.84       NaN
# 3          Misc    123.80     66.09     24.29
# 4  Role-Playing    112.05     75.48    103.54
# 5      Platform       NaN       NaN     15.81
# 6     Adventure       NaN       NaN     15.67

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(16, 6))
fig.autofmt_xdate()
ax1 = sns.barplot(data=genre_all_top, x='genre', y = 'jp_sales', label='jp_sales', ax=ax1)
ax2 = sns.barplot(data=genre_all_top, x='genre', y = 'eu_sales', label = 'eu_sales', ax = ax2)
ax3 = sns.barplot(data=genre_all_top, x='genre', y = 'na_sales', label = 'na_sales', ax = ax3)

# %% [markdown]
# ##### Вывод:
# Во всех регионах популярен жанр Action и Role, в америке и европе первую тройку лидеров занимают одинаковые жанры - Action, Shooter, Sports. В то время как в японии - Role.

# %%
esrb_na = new_year.groupby('rating')['na_sales'].sum().sort_values(ascending = False).reset_index()
esrb_na.columns = ['rating','na_sales']
esrb_na.head(5)
esrb_na = esrb_na.head(5)
esrb_na
# Out:
#          rating  na_sales
# 0             M    382.22
# 1             E    271.15
# 2             T    160.81
# 3          E10+    159.38
# 4  не определен    155.72

# %%
esrb_eu = new_year.groupby('rating')['eu_sales'].sum().sort_values(ascending = False).reset_index()
esrb_eu.columns = ['rating','eu_sales']
esrb_eu.head(5)
esrb_eu = esrb_eu.head(5)
esrb_eu
# Out:
#          rating  eu_sales
# 0             M    292.04
# 1             E    197.34
# 2  не определен    139.44
# 3             T    113.08
# 4          E10+     99.28

# %%
esrb_jp = new_year.groupby('rating')['jp_sales'].sum().sort_values(ascending = False).reset_index()
esrb_jp.columns = ['rating','jp_sales']
esrb_jp.head(5)
esrb_jp = esrb_jp.head(5)
esrb_jp
# Out:
#          rating  jp_sales
# 0  не определен    171.49
# 1             E     47.87
# 2             T     42.11
# 3             M     30.45
# 4          E10+     13.22

# %%
esrb_sale = new_year.groupby('rating')['na_sales', 'eu_sales', 'jp_sales'].sum().sort_values(by='na_sales', ascending=False).reset_index()
esrb_sale
# Out:
#          rating  na_sales  eu_sales  jp_sales
# 0             M    382.22    292.04     30.45
# 1             E    271.15    197.34     47.87
# 2             T    160.81    113.08     42.11
# 3          E10+    159.38     99.28     13.22
# 4  не определен    155.72    139.44    171.49
# 5            EC      1.13      0.00      0.00
# 6            RP      0.00      0.03      0.00

# %% [markdown]
# ##### Вывод:
# Присутствуют 4 основных рейтинга: «E»,«T»,«M» и «E10+».Влияние рейтинга на продажи в разных регионах почти одинаково. На первом месте  «M» ("для взрослых") и «E» в америке и европу, на втором месте для всех регионов рейтинг  "для всех"(https://ru.wikipedia.org/wiki/Entertainment_Software_Rating_Board). Исключение в Японии, там на первом месте по продажам рейтинг не определен (возможно связано с тем, что данные за последние 5 лет и за 2016 данные не полные). Но так как игровая индустрия достаточно динамичная, для прогноза нет смысла брать данные за старые периоды.

# %% [markdown]
# ##  Проверьте гипотезы
# - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# - Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# Задайте самостоятельно пороговое значение alpha.

# %% [markdown]
# #### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
#
# Сформулируем нулевые гипотезы:
#
# Нулевая гипотеза H0: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
#
# Альтернативная гипотеза H1: Средние пользовательские рейтинги платформ Xbox One и PC различаются
#
# нам не нужны сверх точные значения, поэтому alpha = 0.05

# %%
#пропуски в данных для стат тестов надо все удалить. Поэтому сначала возьмем выборку и удалим все лишнее
XOne = new_year.query(' platform == "XOne" ')['user_score'].dropna()
PC = df.query(' platform == "PC" ')['user_score'].dropna()

# %%
#дисперсия
np.var(XOne)
# Out:
# 1.8965188383045526

# %%
np.var(PC)
# Out:
# 2.346112819613175

# %%
#дисперсии отличаются, поэтому в параметр equal = false
alpha = 0.05

results = st.ttest_ind(XOne, PC, equal_var = False)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 4.5385802963771776e-06
# Отвергаем нулевую гипотезу

# %% [markdown]
# ##### Вывод:
# Отвергаем нулевую гипотезу, а значит Средние пользовательские рейтинги платформ Xbox One и PC различаются.

# %% [markdown]
# #### Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные
#
# Сформулируем нулевые гипотезы (H0 всегда со знаком равенства):
#
# Нулевая гипотеза H0: Средние пользовательские рейтинги жанров Action  и Sports одинаковые;
#
# Альтернативная гипотеза H1: Средние пользовательские рейтинги жанров Action  и Sports отличаются
#
# нам не нужны сверх точные значения, поэтому alpha = 0.05

# %%
Action = new_year.query(' genre == "Action" ')['user_score'].dropna()
Sports = new_year.query(' genre == "Sports" ')['user_score'].dropna()

# %%
np.var(Action)
# Out:
# 1.847772513722705

# %%
np.var(Sports)
# Out:
# 2.826632401108592

# %%
#дисперсии отличаются, поэтому в параметр equal = false
alpha = 0.05

results = st.ttest_ind(Action, Sports, equal_var = False)

print('p-значение:', results.pvalue)

if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 1.4516152467844418e-15
# Отвергаем нулевую гипотезу

# %% [markdown]
# ##### Вывод:
# Отвергаем нулевую гипотезу, а значит cредние пользовательские рейтинги жанров Action и Sports отличаются (почти нет вероятности получить одинакове средние рейнтинги по двум жанрам).

# %%
Action = new_year.query(' genre == "Action" ')['user_score'].mean()
Action
# Out:
# 6.781899871630296

# %%
Sports = new_year.query(' genre == "Sports" ')['user_score'].mean()
Sports
# Out:
# 5.901587301587301

# %%
Action = new_year.query(' genre == "Action" ')['user_score'].describe()
Action
# Out:
# count    779.000000
# mean       6.781900
# std        1.360201
# min        1.600000
# 25%        6.000000
# 50%        7.100000
# 75%        7.800000
# max        9.100000
# Name: user_score, dtype: float64

# %%
Sports = new_year.query(' genre == "Sports" ')['user_score'].describe()
Sports
# Out:
# count    315.000000
# mean       5.901587
# std        1.683934
# min        0.200000
# 25%        5.000000
# 50%        6.200000
# 75%        7.200000
# max        9.000000
# Name: user_score, dtype: float64

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Данные были сначала подготовлены для анализа, привела к нижнему регистру таблицы и сами названия колонок. Изменен тип данных где необходимо. В датасете много пропусков, но данные вцелом корректны, плюс пропуски были в важных столбцах для исследования, поэтому почти не были заменены. Определено, что аббревиатура TBD значит to be determined, to be done. То есть данные были нарочно не заполнены.
#
# До 1995 года количество игр выпускалось мало. Видно, что в период после 1995 в релизах игр наступает увеличение количества, игры становятся популярными и более доступными для населения. С   2010 наступает снижение в количестве игр,  релизы падают в 2 раза и далее идут примерно на 1 уровне. На основе анализа был определен срок жизни платформы в 5 лет, соответсвенно после определения дальнейший анализ велся исходя из актуального датасета. По анализу определено, что новые платформы выстреливают и продажи большие, но есть ряд платформ со стабильным циклом, которые однозначно надо включать в план.
# Проведен анализ оценок пользователей и критиков. Оценки критиков взаимосвязаны с продажами самих игр. То есть чем больше оценка критиков , тем лучше продажа игры. А оценки пользователей не влияют на продажи.
# Так же определено, что самый популярный жанр  это Экшн и Role (так как присутсвтует в 3-х регионах). В продажах по жанрам в лидерах опять Action, Sports, и на 3 месте уже Shooter; хуже всего Strategy и  Puzzle.
# В рамках анализа были также проверены гипотезы("Средние пользовательские рейтинги платформ Xbox One и PC одинаковые" - что не подтвердилось;   "Средние пользовательские рейтинги жанров Action и Sports разные" - гипотеза подтвердилась.
#
# По прогнозу на 2017 год можно сказать: перспективные PS3 и X360, PS4 (нужно поддерживать развитие). Перспективные - Wii и XOne, так как появились недавно и еще есть запас активного цикла, поэтому нужно включить в план. Также  еще развивается WiiU достаточно стабильно, PS (как я понимаю это Sony, они всегда актуальны), PSV (поэтому также нужно включить в план в небольших объемах).
